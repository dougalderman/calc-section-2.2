# %%
#Problem 1

# %%
x = var('x')

# %%
def f(x): return 5 - x^2

# %%
d = derivative(f(x), x)

# %%
d
# Out:
# -2*x

# %%
d2 = derivative(f(x), x, 2)

# %%
d2
# Out:
# -2

# %%
d.roots()
# Out:
# [(0, 1)]

# %%
d2.roots()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-33-9e801c8d3494> in <module>
# ----> 1 d2.roots()
#
# /ext/sage/9.4/local/lib/python3.9/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.roots (build/cythonized/sage/symbolic/expression.cpp:62122)()
#   11845         S, mul = self.solve(x, multiplicities=True, explicit_solutions=explicit_solutions)
#   11846         if len(mul) == 0 and explicit_solutions:
# > 11847             raise RuntimeError("no explicit roots found")
#   11848         else:
#   11849             rt_muls = [(S[i].rhs(), mul[i]) for i in range(len(mul))]
#
# RuntimeError: no explicit roots found

# %%
f(0)
# Out:
# 5

# %%
def d2(x): return -2

# %%
d2(0)
# Out:
# -2

# %%
p = []

# %%
p.append(plot(f(x),(x,-5,5), color='blue', legend_label='f(x)'))

# %%
p.append(plot(d,(x,-5,5), color='red', legend_label='d/dx(f(x))'))

# %%
p.append(plot(d2,(x,-5,5), color='orange', legend_label='d2/dx2(f(x))'))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
#Problem 5

# %%
def f(x): return -5*x^2 + 8*x - 7

# %%
d = derivative(f(x), x)

# %%
d
# Out:
# -10*x + 8

# %%
d2 = derivative(f(x), x, 2)

# %%
d2
# Out:
# -10

# %%
d.roots()
# Out:
# [(4/5, 1)]

# %%
d2.roots()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-77-9e801c8d3494> in <module>
# ----> 1 d2.roots()
#
# /ext/sage/9.4/local/lib/python3.9/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.roots (build/cythonized/sage/symbolic/expression.cpp:62122)()
#   11845         S, mul = self.solve(x, multiplicities=True, explicit_solutions=explicit_solutions)
#   11846         if len(mul) == 0 and explicit_solutions:
# > 11847             raise RuntimeError("no explicit roots found")
#   11848         else:
#   11849             rt_muls = [(S[i].rhs(), mul[i]) for i in range(len(mul))]
#
# RuntimeError: no explicit roots found

# %%
f(4/5)
# Out:
# -19/5

# %%
def d2(x): return -10

# %%
d2(4/5)
# Out:
# -10

# %%
p = []

# %%
p.append(plot(f(x),(x,-5,5), color='blue', legend_label='f(x)'))

# %%
p.append(plot(d,(x,-5,5), color='red', legend_label='d/dx(f(x))'))

# %%
p.append(plot(d2,(x,-5,5), color='orange', legend_label='d2/dx2(f(x))'))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
#Problem 9

# %%
def f(x): return x^3 - 12*x

# %%
d = derivative(f(x), x)

# %%
d
# Out:
# 3*x^2 - 12

# %%
d2 = derivative(f(x), x, 2)

# %%
d2
# Out:
# 6*x

# %%
def d2(x): return 6*x

# %%
d.roots()
# Out:
# [(-2, 1), (2, 1)]

# %%
f(-2)
# Out:
# 16

# %%
f(2)
# Out:
# -16

# %%
d2(-2)
# Out:
# -12

# %%
d2(2)
# Out:
# 12

# %%
d2(x).roots()
# Out:
# [(0, 1)]

# %%
f(0)
# Out:
# 0

# %%
d2(-2)
# Out:
# -12

# %%
d2(2)
# Out:
# 12

# %%
p = []

# %%
p.append(plot(f(x),(x,-5,5), color='blue', legend_label='f(x)'))

# %%
p.append(plot(d,(x,-5,5), color='red', legend_label='d/dx(f(x))'))

# %%
p.append(plot(d2,(x,-5,5), color='orange', legend_label='d2/dx2(f(x))'))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
#Problem 13

# %%
def f(x): return (8/3)*x^3 - 2*x + (1/3)

# %%
d = derivative(f(x), x)

# %%
d
# Out:
# 8*x^2 - 2

# %%
d2 = derivative(f(x), x, 2)

# %%
d2
# Out:
# 16*x

# %%
def d2(x): return 16*x

# %%
d.roots()
# Out:
# [(-1/2, 1), (1/2, 1)]

# %%
f(-1/2)
# Out:
# 1

# %%
f(1/2)
# Out:
# -1/3

# %%
d2(-1/2)
# Out:
# -8

# %%
d2(1/2)
# Out:
# 8

# %%
d2(x).roots()
# Out:
# [(0, 1)]

# %%
f(0)
# Out:
# 1/3

# %%
p = []

# %%
p.append(plot(f(x),(x,-2,2), color='blue', legend_label='f(x)'))

# %%
p.append(plot(d,(x,-2,2), color='red', legend_label='d/dx(f(x))'))

# %%
p.append(plot(d2,(x,-2,2), color='orange', legend_label='d2/dx2(f(x))'))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
#Problem 17

# %%
def f(x): return 3*x^4 - 16*x^3 + 18*x^2

# %%
d = derivative(f(x), x)

# %%
d
# Out:
# 12*x^3 - 48*x^2 + 36*x

# %%
d2 = derivative(f(x), x, 2)

# %%
d2
# Out:
# 36*x^2 - 96*x + 36

# %%
def d2(x): return 36*x^2 - 96*x + 36

# %%
d.roots()
# Out:
# [(3, 1), (1, 1), (0, 1)]

# %%
f(0)
# Out:
# 0

# %%
f(1)
# Out:
# 5

# %%
f(3)
# Out:
# -27

# %%
d2(0)
# Out:
# 36

# %%
d2(1)
# Out:
# -24

# %%
d2(3)
# Out:
# 72

# %%
d2(x).roots()
# Out:
# [(-1/3*sqrt(7) + 4/3, 1), (1/3*sqrt(7) + 4/3, 1)]

# %%
numerical_approx(-1/3*sqrt(7) + 4/3, digits=3)
# Out:
# 0.451

# %%
f(-1/3*sqrt(7) + 4/3)
# Out:
# 1/27*(sqrt(7) - 4)^4 + 16/27*(sqrt(7) - 4)^3 + 2*(sqrt(7) - 4)^2

# %%
numerical_approx(1/27*(sqrt(7) - 4)^4 + 16/27*(sqrt(7) - 4)^3 + 2*(sqrt(7) - 4)^2, digits=4)
# Out:
# 2.321

# %%
numerical_approx(1/3*sqrt(7) + 4/3, digits=4)
# Out:
# 2.215

# %%
f(1/3*sqrt(7) + 4/3)
# Out:
# 1/27*(sqrt(7) + 4)^4 - 16/27*(sqrt(7) + 4)^3 + 2*(sqrt(7) + 4)^2

# %%
numerical_approx(1/27*(sqrt(7) + 4)^4 - 16/27*(sqrt(7) + 4)^3 + 2*(sqrt(7) + 4)^2, digits=5)
# Out:
# -13.358

# %%
f(x).roots()
# Out:
# [(-1/3*sqrt(10) + 8/3, 1), (1/3*sqrt(10) + 8/3, 1), (0, 2)]

# %%
numerical_approx(-1/3*sqrt(10) + 8/3, digits=4)
# Out:
# 1.613

# %%
numerical_approx(1/3*sqrt(10) + 8/3, digits=4)
# Out:
# 3.721

# %%
p = []

# %%
p.append(plot(f(x),(x,-1,4), color='blue', legend_label='f(x)'))

# %%
p.append(plot(d,(x,-1,4), color='red', legend_label='d/dx(f(x))'))

# %%
p.append(plot(d2,(x,-1,4), color='orange', legend_label='d2/dx2(f(x))'))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
#Problem 21

# %%
def f(x): return x^3 - 2*x^2 - 4*x + 3

# %%
d = derivative(f(x), x)

# %%
d
# Out:
# 3*x^2 - 4*x - 4

# %%
d2 = derivative(f(x), x, 2)

# %%
d2
# Out:
# 6*x - 4

# %%
def d2(x): return 6*x - 4

# %%
d.roots()
# Out:
# [(-2/3, 1), (2, 1)]

# %%
f(-2/3)
# Out:
# 121/27

# %%
f(2)
# Out:
# -5

# %%
d2(-2/3)
# Out:
# -8

# %%
d2(2)
# Out:
# 8

# %%
d2(x).roots()
# Out:
# [(2/3, 1)]

# %%
f(2/3)
# Out:
# -7/27

# %%
d2(0)
# Out:
# -4

# %%
d2(1)
# Out:
# 2

# %%
p = []

# %%
p.append(plot(f(x),(x,-2,3), color='blue', legend_label='f(x)'))

# %%
p.append(plot(d,(x,-2,3), color='red', legend_label='d/dx(f(x))'))

# %%
p.append(plot(d2,(x,-2,3), color='orange', legend_label='d2/dx2(f(x))'))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
#Problem 25

# %%
def f(x): return x^3 - 6*x^2 - 135*x

# %%
d = derivative(f(x), x)

# %%
d
# Out:
# 3*x^2 - 12*x - 135

# %%
d2 = derivative(f(x), x, 2)

# %%
d2
# Out:
# 6*x - 12

# %%
def d2(x): return 6*x - 12

# %%
d.roots()
# Out:
# [(9, 1), (-5, 1)]

# %%
f(-5)
# Out:
# 400

# %%
f(9)
# Out:
# -972

# %%
d2(-5)
# Out:
# -42

# %%
d2(9)
# Out:
# 42

# %%
d2(x).roots()
# Out:
# [(2, 1)]

# %%
f(2)
# Out:
# -286

# %%
d2(0)
# Out:
# -12

# %%
d2(5)
# Out:
# 18

# %%
f(x).roots()
# Out:
# [(15, 1), (-9, 1), (0, 1)]

# %%
p = []

# %%
p.append(plot(f(x),(x,-10,17), color='blue', legend_label='f(x)'))

# %%
p.append(plot(d,(x,-10,17), color='red', legend_label='d/dx(f(x))'))

# %%
p.append(plot(d2,(x,-10,17), color='orange', legend_label='d2/dx2(f(x))'))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
#Problem 29

# %%
def f(x): return x^3 - 6*x^2 + 12*x - 6

# %%
d = derivative(f(x), x)

# %%
d
# Out:
# 3*x^2 - 12*x + 12

# %%
d2 = derivative(f(x), x, 2)

# %%
d2
# Out:
# 6*x - 12

# %%
def d2(x): return 6*x - 12

# %%
d.roots()
# Out:
# [(2, 2)]

# %%
f(2)
# Out:
# 2

# %%
d2(2)
# Out:
# 0

# %%
def d(x): return 3*x^2 - 12*x + 12

# %%
d(0)
# Out:
# 12

# %%
d(3)
# Out:
# 3

# %%
d2(x).roots()
# Out:
# [(2, 1)]

# %%
d2(0)
# Out:
# -12

# %%
d2(3)
# Out:
# 6

# %%
p = []

# %%
p.append(plot(f(x),(x,-1,5), color='blue', legend_label='f(x)'))

# %%
p.append(plot(d,(x,-1,5), color='red', legend_label='d/dx(f(x))'))

# %%
p.append(plot(d2,(x,-1,5), color='orange', legend_label='d2/dx2(f(x))'))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
#Problem 33

# %%
def f(x): return x^2*(3-x)^2

# %%
d = derivative(f(x), x)

# %%
d
# Out:
# 2*(x - 3)^2*x + 2*(x - 3)*x^2

# %%
d2 = derivative(f(x), x, 2)

# %%
d2
# Out:
# 2*(x - 3)^2 + 8*(x - 3)*x + 2*x^2

# %%
def d2(x): return 2*(x - 3)^2 + 8*(x - 3)*x + 2*x^2

# %%
d.roots()
# Out:
# [(3/2, 1), (0, 1), (3, 1)]

# %%
f(0)
# Out:
# 0

# %%
f(3/2)
# Out:
# 81/16

# %%
f(3)
# Out:
# 0

# %%
d2(0)
# Out:
# 18

# %%
d2(3/2)
# Out:
# -9

# %%
d2(3)
# Out:
# 18

# %%
d2(x).roots()
# Out:
# [(-1/2*sqrt(3) + 3/2, 1), (1/2*sqrt(3) + 3/2, 1)]

# %%
numerical_approx(-1/2*sqrt(3) + 3/2, digits=4)
# Out:
# 0.6340

# %%
numerical_approx(1/2*sqrt(3) + 3/2, digits=5)
# Out:
# 2.3660

# %%
f(-1/2*sqrt(3) + 3/2)
# Out:
# 1/16*(sqrt(3) + 3)^2*(sqrt(3) - 3)^2

# %%
numerical_approx(1/16*(sqrt(3) + 3)^2*(sqrt(3) - 3)^2, digits=5)
# Out:
# 2.2500

# %%
f(1/2*sqrt(3) + 3/2)
# Out:
# 1/16*(sqrt(3) + 3)^2*(sqrt(3) - 3)^2

# %%
numerical_approx(1/16*(sqrt(3) + 3)^2*(sqrt(3) - 3)^2)
# Out:
# 2.25000000000000

# %%
d2(0)
# Out:
# 18

# %%
d2(3/2)
# Out:
# -9

# %%
d2(3)
# Out:
# 18

# %%
p = []

# %%
p.append(plot(f(x),(x,-1.5,4.5), color='blue', legend_label='f(x)'))

# %%
p.append(plot(d,(x,-1.5,4.5), color='red', legend_label='d/dx(f(x))'))

# %%
p.append(plot(d2,(x,-1.5,4.5), color='orange', legend_label='d2/dx2(f(x))'))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
#Problem 37

# %%
def f(x): return (x-3)^(1/3) - 1

# %%
d = derivative(f(x), x)

# %%
d
# Out:
# 1/3/(x - 3)^(2/3)

# %%
d2 = derivative(f(x), x, 2)

# %%
d2
# Out:
# -2/9/(x - 3)^(5/3)

# %%
def d2(x): return -2/9/(x - 3)^(5/3)

# %%
d.roots()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-130-d6ece07eb299> in <module>
# ----> 1 d.roots()
#
# /ext/sage/9.4/local/lib/python3.9/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.roots (build/cythonized/sage/symbolic/expression.cpp:62122)()
#   11845         S, mul = self.solve(x, multiplicities=True, explicit_solutions=explicit_solutions)
#   11846         if len(mul) == 0 and explicit_solutions:
# > 11847             raise RuntimeError("no explicit roots found")
#   11848         else:
#   11849             rt_muls = [(S[i].rhs(), mul[i]) for i in range(len(mul))]
#
# RuntimeError: no explicit roots found

# %%
f(3)
# Out:
# -1

# %%
d2(3)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-132-e0a7745de01b> in <module>
# ----> 1 d2(Integer(3))
#
# <ipython-input-129-d6e35b567f20> in d2(x)
# ----> 1 def d2(x): return -Integer(2)/Integer(9)/(x - Integer(3))**(Integer(5)/Integer(3))
#
# /ext/sage/9.4/local/lib/python3.9/site-packages/sage/rings/rational.pyx in sage.rings.rational.Rational.__truediv__ (build/cythonized/sage/rings/rational.cpp:21283)()
#    2448         if type(left) is type(right):
#    2449             if mpq_cmp_si((<Rational> right).value, 0, 1) == 0:
# -> 2450                 raise ZeroDivisionError('rational division by zero')
#    2451             x = <Rational> Rational.__new__(Rational)
#    2452             mpq_div(x.value, (<Rational>left).value, (<Rational>right).value)
#
# ZeroDivisionError: rational division by zero

# %%
def d(x): return 1/3/(x - 3)^(2/3)

# %%
d(2)
# Out:
# -1/3*(-1)^(1/3)

# %%
d(4)
# Out:
# 1/3

# %%
d2(2)
# Out:
# -2/9*(-1)^(1/3)

# %%
d2(4)
# Out:
# -2/9

# %%
p = []

# %%
def f_graph(x): return sign(x-3)*abs(x-3)^(1/3) - 1

# %%
def d_graph(x): return 1/3/sign(x-3)*abs(x-3)^(2/3)

# %%
def d2_graph(x): return -2/9/sign(x-3)*abs(x-3)^(5/3)

# %%
p.append(plot(f_graph(x),(x,-2,6), color='blue', legend_label='f(x)'))

# %%
p.append(plot(d_graph(x),(x,-2,6), color='red', legend_label='d/dx(f(x))'))

# %%
p.append(plot(d2_graph(x),(x,-2,6), color='orange', legend_label='d2/dx2(f(x))'))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
#Problem 41

# %%
def f(x): return x*sqrt(4-x^2)

# %%
d = derivative(f(x), x)

# %%
d
# Out:
# -x^2/sqrt(-x^2 + 4) + sqrt(-x^2 + 4)

# %%
d2 = derivative(f(x), x, 2)

# %%
d2
# Out:
# -x^3/(-x^2 + 4)^(3/2) - 3*x/sqrt(-x^2 + 4)

# %%
def d2(x): return -x^3/(-x^2 + 4)^(3/2) - 3*x/sqrt(-x^2 + 4)

# %%
d.roots()
# Out:
# [(-sqrt(2), 1), (sqrt(2), 1)]

# %%
f(sqrt(2))
# Out:
# 2

# %%
f(-sqrt(2))
# Out:
# -2

# %%
f(2)
# Out:
# 0

# %%
f(-2)
# Out:
# 0

# %%
d2(sqrt(2))
# Out:
# -4

# %%
d2(-sqrt(2))
# Out:
# 4

# %%
d2(2)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-177-6091a0c7f23b> in <module>
# ----> 1 d2(Integer(2))
#
# <ipython-input-169-4971775f8624> in d2(x)
# ----> 1 def d2(x): return -x**Integer(3)/(-x**Integer(2) + Integer(4))**(Integer(3)/Integer(2)) - Integer(3)*x/sqrt(-x**Integer(2) + Integer(4))
#
# /ext/sage/9.4/local/lib/python3.9/site-packages/sage/rings/integer.pyx in sage.rings.integer.Integer.__truediv__ (build/cythonized/sage/rings/integer.c:14424)()
#    2044         elif type(right) is Rational:
#    2045             if mpq_sgn((<Rational>right).value) == 0:
# -> 2046                 raise ZeroDivisionError("rational division by zero")
#    2047             # left * den(right) / num(right)
#    2048             y = <Rational> Rational.__new__(Rational)
#
# ZeroDivisionError: rational division by zero

# %%
d2(-2)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-178-8fd8d2534670> in <module>
# ----> 1 d2(-Integer(2))
#
# <ipython-input-169-4971775f8624> in d2(x)
# ----> 1 def d2(x): return -x**Integer(3)/(-x**Integer(2) + Integer(4))**(Integer(3)/Integer(2)) - Integer(3)*x/sqrt(-x**Integer(2) + Integer(4))
#
# /ext/sage/9.4/local/lib/python3.9/site-packages/sage/rings/integer.pyx in sage.rings.integer.Integer.__truediv__ (build/cythonized/sage/rings/integer.c:14424)()
#    2044         elif type(right) is Rational:
#    2045             if mpq_sgn((<Rational>right).value) == 0:
# -> 2046                 raise ZeroDivisionError("rational division by zero")
#    2047             # left * den(right) / num(right)
#    2048             y = <Rational> Rational.__new__(Rational)
#
# ZeroDivisionError: rational division by zero

# %%
d2(x).roots()
# Out:
# [(-sqrt(6), 1), (sqrt(6), 1), (0, 1)]

# %%
f(-sqrt(6))
# Out:
# -sqrt(6)*sqrt(-2)

# %%
f(sqrt(6))
# Out:
# sqrt(6)*sqrt(-2)

# %%
f(0)
# Out:
# 0

# %%
p = []

# %%
p.append(plot(f(x),(x,-2,2), color='blue', legend_label='f(x)'))

# %%
p.append(plot(d,(x,-1.9,1.9), color='red', legend_label='d/dx(f(x))'))

# %%
p.append(plot(d2,(x,-1.7,1.7), color='orange', legend_label='d2/dx2(f(x))'))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
#Problem 45

# %%
def f(x): return 3/(x^2+1)

# %%
d = derivative(f(x), x)

# %%
d
# Out:
# -6*x/(x^2 + 1)^2

# %%
d2 = derivative(f(x), x, 2)

# %%
d2
# Out:
# 24*x^2/(x^2 + 1)^3 - 6/(x^2 + 1)^2

# %%
def d2(x): return 24*x^2/(x^2 + 1)^3 - 6/(x^2 + 1)^2

# %%
d.roots()
# Out:
# [(0, 1)]

# %%
f(0)
# Out:
# 3

# %%
d2(0)
# Out:
# -6

# %%
d2(x).roots()
# Out:
# [(-1/3*sqrt(3), 1), (1/3*sqrt(3), 1)]

# %%
f(-1/3*sqrt(3))
# Out:
# 9/4

# %%
f(1/3*sqrt(3))
# Out:
# 9/4

# %%
d2(-1)
# Out:
# 3/2

# %%
d2(1)
# Out:
# 3/2

# %%
p = []

# %%
p.append(plot(f(x),(x,-2,2), color='blue', legend_label='f(x)'))

# %%
p.append(plot(d,(x,-2,2), color='red', legend_label='d/dx(f(x))'))

# %%
p.append(plot(d2,(x,-2,2), color='orange', legend_label='d2/dx2(f(x))'))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
#Problem 103

# %%
def p(x): return (13*x^3 - 240*x^2 - 2460*x + 585000)/75000

# %%
d = derivative(p(x), x)

# %%
d
# Out:
# 13/25000*x^2 - 4/625*x - 41/1250

# %%
d2 = derivative(p(x), x, 2)

# %%
d2
# Out:
# 13/12500*x - 4/625

# %%
def d2(x): return 13/12500*x - 4/625

# %%
d.roots()
# Out:
# [(-2/13*sqrt(4265) + 80/13, 1), (2/13*sqrt(4265) + 80/13, 1)]

# %%
numerical_approx(-2/13*sqrt(4265) + 80/13, digits=5)
# Out:
# -3.8934

# %%
numerical_approx(2/13*sqrt(4265) + 80/13, digits=5)
# Out:
# 16.201

# %%
p(2/13*sqrt(4265) + 80/13)
# Out:
# 1/1584375*(sqrt(4265) + 40)^3 - 8/105625*(sqrt(4265) + 40)^2 - 41/8125*sqrt(4265) + 12347/1625

# %%
numerical_approx(1/1584375*(sqrt(4265) + 40)^3 - 8/105625*(sqrt(4265) + 40)^2 - 41/8125*sqrt(4265) + 12347/1625, digits=5)
# Out:
# 7.1658

# %%
d2(2/13*sqrt(4265) + 80/13)
# Out:
# 1/6250*sqrt(4265)

# %%
d2(x).roots()
# Out:
# [(80/13, 1)]

# %%
p(80/13)
# Out:
# 476413/63375

# %%
numerical_approx(80/13, digits=5)
# Out:
# 6.1538

# %%
numerical_approx(476413/63375, digits=5)
# Out:
# 7.5174

# %%
d2(0)
# Out:
# -4/625

# %%
d2(7)
# Out:
# 11/12500

# %%
plot(p(x),(x,0,40), color='blue', legend_label='f(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
pr = []

# %%
pr.append(plot(d,(x,0,40), color='red', legend_label='d/dx(f(x))'))

# %%
pr.append(plot(d2,(x,0,40), color='orange', legend_label='d2/dx2(f(x))'))

# %%
sum(pr)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#Problem 115

# %%
def f(x): return x^2*(1-x)^3

# %%
d = derivative(f(x), x)

# %%
d
# Out:
# -2*(x - 1)^3*x - 3*(x - 1)^2*x^2

# %%
d2 = derivative(f(x), x, 2)

# %%
d2
# Out:
# -2*(x - 1)^3 - 12*(x - 1)^2*x - 6*(x - 1)*x^2

# %%
def d2(x): return -2*(x - 1)^3 - 12*(x - 1)^2*x - 6*(x - 1)*x^2

# %%
d.roots()
# Out:
# [(2/5, 1), (0, 1), (1, 2)]

# %%
f(2/5)
# Out:
# 108/3125

# %%
numerical_approx(108/3125, digits=5)
# Out:
# 0.034560

# %%
f(0)
# Out:
# 0

# %%
f(1)
# Out:
# 0

# %%
d2(2/5)
# Out:
# -18/25

# %%
d2(0)
# Out:
# 2

# %%
d2(1)
# Out:
# 0

# %%
def d(x): return -2*(x - 1)^3*x - 3*(x - 1)^2*x^2

# %%
d(4/5)
# Out:
# -8/125

# %%
d(2)
# Out:
# -16

# %%
d2(x).roots()
# Out:
# [(-1/10*sqrt(6) + 2/5, 1), (1/10*sqrt(6) + 2/5, 1), (1, 1)]

# %%
numerical_approx(-1/10*sqrt(6) + 2/5, digits=5)
# Out:
# 0.15505

# %%
numerical_approx(1/10*sqrt(6) + 2/5, digits=5)
# Out:
# 0.64495

# %%
f(-1/10*sqrt(6) + 2/5)
# Out:
# 1/100000*(sqrt(6) + 6)^3*(sqrt(6) - 4)^2

# %%
numerical_approx(1/100000*(sqrt(6) + 6)^3*(sqrt(6) - 4)^2, digits=5)
# Out:
# 0.014502

# %%
f(1/10*sqrt(6) + 2/5)
# Out:
# -1/100000*(sqrt(6) + 4)^2*(sqrt(6) - 6)^3

# %%
numerical_approx(-1/100000*(sqrt(6) + 4)^2*(sqrt(6) - 6)^3, digits=5)
# Out:
# 0.018618

# %%
d2(4/5)
# Out:
# 2/5

# %%
d2(2)
# Out:
# -50

# %%
plot(f(x),(x,-0.1,1.2), color='blue', legend_label='f(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
p = []

# %%
p.append(plot(d,(x,-0.1,1.2), color='red', legend_label='d/dx(f(x))'))

# %%
p.append(plot(d2,(x,-0.1,1.2), color='orange', legend_label='d2/dx2(f(x))'))

# %%
sum(p)
# Out:
# Graphics object consisting of 2 graphics primitives
